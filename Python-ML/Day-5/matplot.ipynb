# %% [markdown]
# ## install matplotlib

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
help(plt)
# Out:
# Help on package matplotlib:
#
# NAME
#     matplotlib - An object-oriented plotting library.
#
# DESCRIPTION
#     A procedural interface is provided by the companion pyplot module,
#     which may be imported directly, e.g.::
#
#         import matplotlib.pyplot as plt
#
#     or using ipython::
#
#         ipython
#
#     at your terminal, followed by::
#
#         In [1]: %matplotlib
#         In [2]: import matplotlib.pyplot as plt
#
#     at the ipython shell prompt.
#
#     For the most part, direct use of the explicit object-oriented library is
#     encouraged when programming; the implicit pyplot interface is primarily for
#     working interactively. The exceptions to this suggestion are the pyplot
#     functions `.pyplot.figure`, `.pyplot.subplot`, `.pyplot.subplots`, and
#     `.pyplot.savefig`, which can greatly simplify scripting.  See
#     :ref:`api_interfaces` for an explanation of the tradeoffs between the implicit
#     and explicit interfaces.
#
# ...

# %%
x=[0,2,4,6,8]
y=[0,4,16,36,64]

fig,ax=plt.subplots()
ax.plot(x,y,marker='X',label="data points")
ax.set_title("basic components of matplotlib figure")

ax.set_xlabel("x-axis")
ax.set_ylabel("y-axis")
ax.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

# Generate data for the 3D line plot
t = np.linspace(-4 * np.pi, 4 * np.pi, 100)
z = np.linspace(-2, 2, 100)
r = z**2 + 1
x = r * np.sin(t)
y = r * np.cos(t)

# Create a figure and add a 3D subplot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the 3D line
ax.plot(x, y, z, label='3D Spiral')

# Set labels and title
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Z-axis')
ax.set_title('Matplotlib 3D Line Plot')

# Add a legend
ax.legend()

# Display the plot
plt.show()

# %%
arr=np.array([10,20,30])
df=pd.DataFrame({'numbers':arr})
plt.bar(df.index,df['numbers'])
plt.show()

# %%
data={'name':['gopal','shubham','meet','namitha'],
      'age':[20,21,10,9],
      'salary':[10000,20000,12000,45000]
      }
df=pd.DataFrame(data)

# %%
df
# Out:
#       name  age  salary
# 0    gopal   20   10000
# 1  shubham   21   20000
# 2     meet   10   12000
# 3  namitha    9  450000

# %%
plt.Figure(figsize=(10,6))
plt.bar(df['name'],df['salary'])
# ax.plot(name,s?alary,label="salary point")
ax.set_title("basic salary")
ax.set_xlabel("x-axis")
ax.set_ylabel("y-axis")

ax.legend()
plt.show()

# %% [markdown]
# ## install seaborn ans import as sns

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
df=sns.load_dataset('tips')


# df=df.rename(columns={'"Game Lengt?h"': 'Game_Length'})
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.boxplot(x=df['tip'])
# Out:
# <Axes: xlabel='tip'>

# %%
Q1=df.quantile(0.25,numeric_only=True)
Q3=df.quantile(0.75,numeric_only=True)
IQR=Q3-Q1
print(IQR)
col=df.columns
col
# Out:
# total_bill    10.7800
# tip            1.5625
# size           1.0000
# dtype: float64
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
for c in col:
# Out:
#   Cell In[63], line 1
#     for c in col:
#                  ^
# _IncompleteInputError: incomplete input
