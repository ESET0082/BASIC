# %% [markdown]
# # Machine Learning
#
# ## supervised meachine learning -> we have label for data
#
# ### Regression
#
# ### classification
#
#
# ## unsupervised meachine learning -> -> we have label for data
#
# ## Clustering

# %% [markdown]
# # Linear Regression
#
# ### -> 1) Importing require libaries
# ### ->2)  Gathering preprocessed data
# ### ->3)  Choose right model
# ### ->4)  Define a target(y) and feature(x)
# ### ->5)  Spliting our data into train and test
# ### ->6)  Train our model
# ### ->7)  Validate our data
# ### ->8)  Evaluation
# ### ->9)  visualization

# %%
pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/8.7 MB ? eta -:--:--
#    ---------------------- ----------------- 5.0/8.7 MB 30.6 MB/s eta 0:00:01
#    ---------------------------------------- 8.7/8.7 MB 26.1 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/38.5 MB ? eta -:--:--
#    ------- -------------------------------- 7.6/38.5 MB 36.7 MB/s eta 0:00:01
#    ------------ --------------------------- 12.3/38.5 MB 30.3 MB/s eta 0:00:01
#    ------------------- -------------------- 18.4/38.5 MB 30.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 22.8/38.5 MB 28.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 27.0/38.5 MB 26.6 MB/s eta 0:00:01
#    -------------------------------- ------- 30.9/38.5 MB 25.7 MB/s eta 0:00:01
#    ------------------------------------ --- 34.9/38.5 MB 24.7 MB/s eta 0:00:01
# ...

# %%
import sklearn
